# %%
print('logic one')
print("logic two")
l1 : list[int] = [1,2,3]
try:
    print(5/2)
    print(l1[0])
    print(xyz)
except (ZeroDivisionError,IndexError,NameError):
    print("zero division Error")
print("logic 4")
print("logic 5")
# Out:
# logic one
# logic two
# 2.5
# 1
# zero division Error
# logic 4
# logic 5

# %%
print('logic one')
print("logic two")
li : list[int] = [1,2,3]
try:
    print(5/2)
    print(li[0])
    print(xyz)
except (ZeroDivisionError):
    print("zero division Error")
except(IndexError):
    print("IndexError")
except(NameError):
    print("NameError")
except: 
    print("some thing wrong")
print("logic 4")
print("logic 5")
# Out:
# logic one
# logic two
# 2.5
# 1
# NameError
# logic 4
# logic 5

# %%
try:
    print(age)
    print(li[200])
except Exception as e:
    print(f"Some thing is wrong\n {e}")

# %%
class StudentCard():
    def __init__(self, roll_no: int, name:str,age:int)-> None:
        if age < 18 or age> 60 :
            raise StudentAgeError("your are not Eligible for this program")
        self.roll_no = roll_no
        self.name = name
        self.age = age
        
            
class StudentAgeError(Exception):
    pass

student1 = StudentCard(1,"aqib khan",30)

print(student1.name,student1.roll_no,student1.age)
# Out:
# aqib khan 1 30

# %%
student1 = StudentCard(1,"aqib khan",61)

print(student1.name,student1.roll_no,student1.age)
# Out:
# ---------------------------------------------------------------------------
# StudentAgeError                           Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 student1 = StudentCard(1,"aqib khan",61)
#       3 print(student1.name,student1.roll_no,student1.age)
#
# Cell In[14], line 4, in StudentCard.__init__(self, roll_no, name, age)
#       2 def __init__(self, roll_no: int, name:str,age:int)-> None:
#       3     if age < 18 or age> 60 :
# ----> 4         raise StudentAgeError("your are not Eligible for this program")
#       5     self.roll_no = roll_no
#       6     self.name = name
#
# StudentAgeError: your are not Eligible for this program

# %%
open('./abc.txt')
# Out:
# <_io.TextIOWrapper name='./abc.txt' mode='r' encoding='utf-8'>

# %%
from typing import TextIO
data :TextIO = open('./abc.txt')
print(data.read())

# [i for i in dir(data) if "__" not in i]

# %%
from typing import TextIO
data :TextIO = open('./abc.txt')
print(data.read())

data.close()
# Out:
# line1
# line2
# line3
# line4
# line5
# line6

# %%
with open('./abc.txt',"r") as file :
    try:
        print(file.read())
        file.write("pakistan Zindabad")
    except:
        print("Your have no acess to write or edit")
# Out:
# line1
# line2
# line3
# line4
#
# Your have no acess to write or edit

# %%
import pandas as pd
df : pd.DataFrame = pd.read_csv("./data.csv")
df
# Out:
#    id       name   education
# 0   1  aqib khan  Graduation
# 1   2  Amir Khan      Master
# 2   3    Sir Zia      Master

# %%
import pandas as pd
df : pd.DataFrame = pd.read_excel("Islamic Studies.xlsx")
df
# Out:
#                                   UNIVERSITY OF OKARA  \
# 0                        Department of Bioinformatics
# 1                            Assessment /Result Sheet
# 2                                     Programme Name:
# 3                                      Course Title:
# 4                                     Campus Roll No.
# 5                                                 NaN
# 6                                                 NaN
# 7                                  F23-BSBIOINFO-1001
# 8                                  F23-BSBIOINFO-1002
# 9                                  F23-BSBIOINFO-1003
# 10                                 F23-BSBIOINFO-1004
# 11                                 F23-BSBIOINFO-1005
# 12                                 F23-BSBIOINFO-1006
# 13                                 F23-BSBIOINFO-1007
# 14                                 F23-BSBIOINFO-1008
# 15                                 F23-BSBIOINFO-1009
# ...
